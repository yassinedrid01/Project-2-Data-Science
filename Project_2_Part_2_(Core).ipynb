# %% [markdown]
# <a href="https://colab.research.google.com/github/yassinedrid01/Project-2-Data-Science/blob/main/Project_2_Part_2_(Core).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('/content/archive.zip')
df1.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
df1.shape
# Out:
# (48842, 15)

# %%
df1.duplicated().sum()
# Out:
# 52

# %%
df1=df1.drop_duplicates()

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48790 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48790 non-null  int64
#  1   workclass        48790 non-null  object
#  2   fnlwgt           48790 non-null  int64
#  3   education        48790 non-null  object
#  4   educational-num  48790 non-null  int64
#  5   marital-status   48790 non-null  object
#  6   occupation       48790 non-null  object
#  7   relationship     48790 non-null  object
#  8   race             48790 non-null  object
#  9   gender           48790 non-null  object
#  10  capital-gain     48790 non-null  int64
#  11  capital-loss     48790 non-null  int64
#  12  hours-per-week   48790 non-null  int64
#  13  native-country   48790 non-null  object
#  14  income           48790 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 6.0+ MB

# %%
df1.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48790.000000  4.879000e+04     48790.000000  48790.000000
# mean      38.652798  1.896690e+05        10.078807   1080.217688
# std       13.708493  1.056172e+05         2.570046   7455.905921
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175550e+05         9.000000      0.000000
# 50%       37.000000  1.781385e+05        10.000000      0.000000
# 75%       48.000000  2.376062e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48790.000000    48790.000000
# mean      87.595573       40.425886
# std      403.209129       12.392729
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
df1['gender'].value_counts()
# Out:
# Male      32614
# Female    16176
# Name: gender, dtype: int64

# %%
df1['marital-status'].value_counts()
# Out:
# Married-civ-spouse       22366
# Never-married            16082
# Divorced                  6630
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      627
# Married-AF-spouse           37
# Name: marital-status, dtype: int64

# %%
df1['workclass'].value_counts()
# Out:
# Private             33860
# Self-emp-not-inc     3861
# Local-gov            3136
# ?                    2795
# State-gov            1981
# Self-emp-inc         1694
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: workclass, dtype: int64

# %%
df1=df1.replace('?',np.nan)

# %%
df1.isna().sum()
# Out:
# age                   0
# workclass          2795
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2805
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      856
# income                0
# dtype: int64

# %%
most_commun_workclass=df1['workclass'].mode().iloc[0]
df1['workclass'].fillna(most_commun_workclass,inplace=True)

# %%
most_commun_occupation=df1['occupation'].mode().iloc[0]
df1['occupation'].fillna(most_commun_occupation,inplace=True)

# %%
most_commun_country=df1['native-country'].mode().iloc[0]
df1['native-country'].fillna(most_commun_country,inplace=True)

# %%
df1.isna().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df1['income'].hist()
# Out:
# <Axes: >

# %%
corr=df1.corr()
sns.heatmap(corr, cmap = 'Greens',annot=True)
# Out:
# <ipython-input-26-583d06295f78>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df1.corr()
# <Axes: >

# %%
df2=pd.read_csv('/content/Metabolic  Syndrome.csv')
df2.head()
# Out:
#     seqn  Age     Sex  Marital  Income   Race  WaistCirc   BMI  Albuminuria  \
# 0  62161   22    Male   Single  8200.0  White       81.0  23.3            0
# 1  62164   44  Female  Married  4500.0  White       80.1  23.2            0
# 2  62169   21    Male   Single   800.0  Asian       69.6  20.1            0
# 3  62172   43  Female   Single  2000.0  Black      120.4  33.3            0
# 4  62177   51    Male  Married     NaN  Asian       81.1  20.1            0
#
#    UrAlbCr  UricAcid  BloodGlucose  HDL  Triglycerides MetabolicSyndrome
# 0     3.88       4.9            92   41             84         No MetSyn
# 1     8.55       4.5            82   28             56         No MetSyn
# 2     5.07       5.4           107   43             78         No MetSyn
# 3     5.22       5.0           104   73            141         No MetSyn
# 4     8.13       5.0            95   43            126         No MetSyn

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2401 entries, 0 to 2400
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   seqn               2401 non-null   int64
#  1   Age                2401 non-null   int64
#  2   Sex                2401 non-null   object
#  3   Marital            2193 non-null   object
#  4   Income             2284 non-null   float64
#  5   Race               2401 non-null   object
#  6   WaistCirc          2316 non-null   float64
#  7   BMI                2375 non-null   float64
#  8   Albuminuria        2401 non-null   int64
#  9   UrAlbCr            2401 non-null   float64
#  10  UricAcid           2401 non-null   float64
#  11  BloodGlucose       2401 non-null   int64
#  12  HDL                2401 non-null   int64
#  13  Triglycerides      2401 non-null   int64
#  14  MetabolicSyndrome  2401 non-null   object
# dtypes: float64(5), int64(6), object(4)
# ...

# %%
df2.describe()
# Out:
#                seqn          Age       Income    WaistCirc          BMI  \
# count   2401.000000  2401.000000  2284.000000  2316.000000  2375.000000
# mean   67030.674302    48.691795  4005.253940    98.307254    28.702189
# std     2823.565114    17.632852  2954.032186    16.252634     6.662242
# min    62161.000000    20.000000   300.000000    56.200000    13.400000
# 25%    64591.000000    34.000000  1600.000000    86.675000    24.000000
# 50%    67059.000000    48.000000  2500.000000    97.000000    27.700000
# 75%    69495.000000    63.000000  6200.000000   107.625000    32.100000
# max    71915.000000    80.000000  9000.000000   176.000000    68.700000
#
#        Albuminuria      UrAlbCr     UricAcid  BloodGlucose          HDL  \
# count  2401.000000  2401.000000  2401.000000   2401.000000  2401.000000
# mean      0.154102    43.626131     5.489046    108.247813    53.369429
# std       0.422780   258.272829     1.439358     34.820657    15.185537
# ...

# %%
df2['Race'].value_counts()
# Out:
# White          933
# Black          548
# Asian          349
# Hispanic       257
# MexAmerican    253
# Other           61
# Name: Race, dtype: int64

# %%
df2['Sex'].value_counts()
# Out:
# Female    1211
# Male      1190
# Name: Sex, dtype: int64

# %%
df2['MetabolicSyndrome'].value_counts()
# Out:
# No MetSyn    1579
# MetSyn        822
# Name: MetabolicSyndrome, dtype: int64

# %%
df2['MetabolicSyndrome'].hist()
# Out:
# <Axes: >

# %%
corr2=df2.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr2,cmap='Pastel1',annot=True)
# Out:
# <ipython-input-45-5e03691fcc8f>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr2=df2.corr()
# <Axes: >
